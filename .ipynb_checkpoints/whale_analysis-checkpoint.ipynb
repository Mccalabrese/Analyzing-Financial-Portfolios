# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_path = Path("Resources/whale_returns.csv")
whale_df = pd.read_csv(whale_path)
whale_df['Date'] = pd.to_datetime(whale_df['Date'])
whale_df.set_index('Date', inplace=True)

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_path = Path("Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_path)
algo_df['Date'] = pd.to_datetime(algo_df['Date'])
algo_df.set_index('Date', inplace=True)

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_path = Path("Resources/sp500_history.csv")
sp500_df = pd.read_csv(sp500_path)
sp500_df['Date'] = pd.to_datetime(sp500_df['Date'])
sp500_df.set_index('Date', inplace=True)
# Out:
# /var/folders/5m/7yfwqfkn3hs5pf3sylkksfc40000gn/T/ipykernel_58981/2132427832.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_df['Date'] = pd.to_datetime(sp500_df['Date'])

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df['SP500'] = sp500_df['Close'].str.replace('$', '').astype(float)
sp500_df.dtypes
# Out:
# Close     object
# SP500    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500_returns = sp500_df['SP500'].pct_change()
sp500_returns.head()
# Out:
# Date
# 2019-04-23         NaN
# 2019-04-22   -0.008764
# 2019-04-18   -0.001011
# 2019-04-17   -0.001577
# 2019-04-16    0.002279
# Name: SP500, dtype: float64

# %%
# Drop nulls
sp500_returns.dropna(inplace=True)
sp500_returns
# Out:
# Date
# 2019-04-22   -0.008764
# 2019-04-18   -0.001011
# 2019-04-17   -0.001577
# 2019-04-16    0.002279
# 2019-04-15   -0.000509
#                 ...
# 2012-10-05    0.003469
# 2012-10-04    0.000322
# 2012-10-03   -0.007123
# 2012-10-02   -0.003611
# 2012-10-01   -0.000872
# Name: SP500, Length: 1648, dtype: float64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns.columns = ['S&P TSX']

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, sp500_returns], axis="columns", join="inner")
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot()


# Select the columns you want to include in cumulative returns calculation
selected_columns = [
    'SOROS FUND MANAGEMENT LLC', 
    'PAULSON & CO.INC. ', 
    'TIGER GLOBAL MANAGEMENT LLC', 
    'BERKSHIRE HATHAWAY INC', 
    'Algo 1', 
    'Algo 2', 
    'SP500'
]


# Calculate cumulative returns for selected columns
cumulative_returns = (1 + combined_df[selected_columns]).cumprod() - 1

# Plot cumulative returns
cumulative_returns.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
cumulative_returns.columns = ['SOROS FUND MANAGEMENT LLC', 
    'PAULSON & CO.INC. ', 
    'TIGER GLOBAL MANAGEMENT LLC', 
    'BERKSHIRE HATHAWAY INC', 
    'Algo 1', 
    'Algo 2', 
    'SP500']
cumulative_returns.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of each portfolio
cumulative_returns_std = cumulative_returns.std()

# Print daily standard deviations
print("Daily Standard Deviation (Soros Portfolio):")
print(cumulative_returns_std[0])
print("Daily Standard Deviation (Paulson Portfolio):")
print(cumulative_returns_std[1])
print("Daily Standard Deviation (Tiger Portfolio):")
print(cumulative_returns_std[2])
print("Daily Standard Deviation (Berkshire Portfolio):")
print(cumulative_returns_std[3])
print("Daily Standard Deviation (Algo1 Portfolio):")
print(cumulative_returns_std[4])
print("Daily Standard Deviation (Algo2 Portfolio):")
print(cumulative_returns_std[5])
# Out:
# Daily Standard Deviation (Soros Portfolio):
# 0.07318691830466506
# Daily Standard Deviation (Paulson Portfolio):
# 0.0884470213751215
# Daily Standard Deviation (Tiger Portfolio):
# 0.14965240646520997
# Daily Standard Deviation (Berkshire Portfolio):
# 0.2413819811648785
# Daily Standard Deviation (Algo1 Portfolio):
# 0.23177178454046232
# Daily Standard Deviation (Algo2 Portfolio):
# 0.13164225990327416

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
print("Daily Standard Deviation (S&P 500):")
print(cumulative_returns_std[6])
# Determine which portfolios are riskier than the S&P 500
sp500 = cumulative_returns_std['SP500']
index = 0
for stddev in cumulative_returns_std:
    if stddev > sp500:
        print(f"The {cumulative_returns_std.index[index]} portfolio has more risk than the S&P")
    elif stddev < sp500:
        print(f"The {cumulative_returns_std.index[index]} portfolio has less risk than the S&P")
    else:
        print(f"The {cumulative_returns_std.index[index]} portfolio has the same risk as the S&P")
    index += 1
# Out:
# Daily Standard Deviation (S&P 500):
# 0.11484604096700507
# The SOROS FUND MANAGEMENT LLC portfolio has less risk than the S&P
# The PAULSON & CO.INC.  portfolio has less risk than the S&P
# The TIGER GLOBAL MANAGEMENT LLC portfolio has more risk than the S&P
# The BERKSHIRE HATHAWAY INC portfolio has more risk than the S&P
# The Algo 1 portfolio has more risk than the S&P
# The Algo 2 portfolio has more risk than the S&P
# The SP500 portfolio has the same risk as the S&P

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = cumulative_returns_std * np.sqrt(252)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      1.161806
# PAULSON & CO.INC.              1.404053
# TIGER GLOBAL MANAGEMENT LLC    2.375658
# BERKSHIRE HATHAWAY INC         3.831820
# Algo 1                         3.679263
# Algo 2                         2.089756
# SP500                          1.823124
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolstd = cumulative_returns.rolling(window=21).std()
# Plot the rolling standard deviation
rolstd.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = cumulative_returns.corr()
# Display de correlation matrix

sns.heatmap(correlation, vmin=-1, vmax=1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance = cumulative_returns['SOROS FUND MANAGEMENT LLC'].rolling(window=60).cov(cumulative_returns['SP500'])
covariance
# Calculate variance of S&P 500
variance = cumulative_returns['SP500'].rolling(window=60).var()
variance
# Computing beta
beta_soros = covariance / variance
# Plot beta trend
beta_soros.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
cumulative_returns_std.ewm(halflife=21).mean()
# Out:
# SOROS FUND MANAGEMENT LLC      0.073187
# PAULSON & CO.INC.              0.080943
# TIGER GLOBAL MANAGEMENT LLC    0.104606
# BERKSHIRE HATHAWAY INC         0.140511
# Algo 1                         0.159988
# Algo 2                         0.154865
# SP500                          0.148567
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratio = (combined_df.mean() - cumulative_returns['SP500'].mean())/(cumulative_returns.std())

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind='bar')
# Out:
# <Axes: >

# %%
index=0
algo2 = sharpe_ratio['Algo 2']

for sharpe in sharpe_ratio:
    if sharpe_ratio.index[index] == 'Algo 2':
        continue
    if sharpe < algo2:
        print(f"The {cumulative_returns.columns[index]} portfolio was outperformed by the Algo 2 portfolio")
    elif sharpe > algo2:
        print(f"The {cumulative_returns.columns[index]} portfolio outperformed the Algo 2 portfolio")
    else:
        print(f"The {cumulative_returns.columns[index]} portfolio and the Algo 2 portfolio performed equally")
    index+=1
    
index=0
algo1 = sharpe_ratio['Algo 1']

for sharpe in sharpe_ratio:
    if sharpe_ratio.index[index] == 'Algo 1':
        continue
    if sharpe < algo1:
        print(f"The {cumulative_returns.columns[index]} portfolio was outperformed by the Algo 1 portfolio")
    elif sharpe > algo1:
        print(f"The {cumulative_returns.columns[index]} portfolio outperformed the Algo 1 portfolio")
    else:
        print(f"The {cumulative_returns.columns[index]} portfolio and the Algo 1 portfolio performed equally")
    index+=1
# Out:
# The SOROS FUND MANAGEMENT LLC portfolio outperformed the Algo 2 portfolio
# The PAULSON & CO.INC.  portfolio outperformed the Algo 2 portfolio
# The TIGER GLOBAL MANAGEMENT LLC portfolio was outperformed by the Algo 2 portfolio
# The BERKSHIRE HATHAWAY INC portfolio was outperformed by the Algo 2 portfolio
# The Algo 1 portfolio was outperformed by the Algo 2 portfolio
# The SOROS FUND MANAGEMENT LLC portfolio outperformed the Algo 1 portfolio
# The PAULSON & CO.INC.  portfolio outperformed the Algo 1 portfolio
# The TIGER GLOBAL MANAGEMENT LLC portfolio outperformed the Algo 1 portfolio
# The BERKSHIRE HATHAWAY INC portfolio was outperformed by the Algo 1 portfolio

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
aapl_csv_path = Path("./Resources/aapl_historical.csv")
aapl_df = pd.read_csv(aapl_csv_path, index_col="Trade DATE", parse_dates=True,)

# %%
# Reading data from 2nd stock
cost_csv_path = Path("./Resources/cost_historical.csv")
cost_df = pd.read_csv(cost_csv_path, index_col="Trade DATE", parse_dates=True,)

# %%
# Reading data from 3rd stock
goog_csv_path = Path("./Resources/goog_historical.csv")
goog_df = pd.read_csv(goog_csv_path, index_col="Trade DATE", parse_dates=True,)

# %%
# Combine all stocks in a single DataFrame
customp = pd.concat([aapl_df.NOCP, cost_df.NOCP, goog_df.NOCP], axis="columns", join="inner") 
customp.columns = ['aapl','cost','goog']

# %%
# Reorganize portfolio data by having a column per symbol

customp
# Out:
#               aapl    cost     goog
# Trade DATE
# 2019-05-09  200.72  243.47  1162.38
# 2019-05-08  202.90  241.34  1166.27
# 2019-05-07  202.86  240.18  1174.10
# 2019-05-06  208.48  244.23  1189.39
# 2019-05-03  211.75  244.62  1185.40
# ...            ...     ...      ...
# 2018-05-17  186.99  199.60  1078.59
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-11  188.59  195.76  1098.26
#
# [250 rows x 3 columns]

# %%
# Calculate daily returns
daily_returns = customp.pct_change()
# Drop NAs
daily_returns.dropna(inplace = True)
# Display sample data
daily_returns.head()
# Out:
#                 aapl      cost      goog
# Trade DATE
# 2019-05-08  0.010861 -0.008749  0.003347
# 2019-05-07 -0.000197 -0.004806  0.006714
# 2019-05-06  0.027704  0.016862  0.013023
# 2019-05-03  0.015685  0.001597 -0.003355
# 2019-05-02 -0.012279 -0.007890 -0.019226

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = daily_returns.dot(weights)
# Display sample data
portfolio_returns.head()
# Out:
# Trade DATE
# 2019-05-08    0.001820
# 2019-05-07    0.000570
# 2019-05-06    0.019196
# 2019-05-03    0.004642
# 2019-05-02   -0.013131
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_df['Custom Portfolio'] = portfolio_returns
combined_with_custom = combined_df

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_with_custom.dropna(inplace = True)
combined_with_custom.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2     SP500  Custom Portfolio
# Date
# 2018-05-11  0.000281 -0.000883         -0.000012
# 2018-05-14  0.001635  0.006889          0.010216
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
anstd = combined_with_custom.std() * np.sqrt(252)

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
wcust_std = combined_with_custom.rolling(window=21).mean()
# Plot rolling standard deviation
wcust_std.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
wcust_corr = combined_with_custom.corr()
wcust_corr.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Calculate and plot Beta
wcust_covariance = combined_with_custom['Custom Portfolio'].rolling(window=60).cov(combined_with_custom['SP500'])
wcust_variance = combined_with_custom['SP500'].rolling(window=60).var()

wcust_rolling_beta = wcust_covariance / wcust_variance
wcust_rolling_beta.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratio = ((combined_with_custom.mean()-combined_with_custom['SP500'].mean()) * 252) / (combined_with_custom.std() * 252)

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
index = 0
cus_p_std = sharpe_ratio['Custom Portfolio']
for stddev in cumulative_returns_std:
    if sharpe_ratio.index[index] == 'Custom Portfolio':
        continue
    if stddev > cus_p_std:
        print(f"The custom portfolio underpreformed the {cumulative_returns_std.index[index]} portfolio")
    elif stddev < cus_p_std:
        print(f"The custom portfolio outpreformed the {cumulative_returns_std.index[index]} portfolio")
    else:
        print(f"The custom and {cumulative_returns_std.index[index]} portfolio preformed equally")
    index += 1
# Out:
# The custom portfolio underpreformed the SOROS FUND MANAGEMENT LLC portfolio
# The custom portfolio underpreformed the PAULSON & CO.INC.  portfolio
# The custom portfolio underpreformed the TIGER GLOBAL MANAGEMENT LLC portfolio
# The custom portfolio underpreformed the BERKSHIRE HATHAWAY INC portfolio
# The custom portfolio underpreformed the Algo 1 portfolio
# The custom portfolio underpreformed the Algo 2 portfolio
# The custom portfolio underpreformed the SP500 portfolio
